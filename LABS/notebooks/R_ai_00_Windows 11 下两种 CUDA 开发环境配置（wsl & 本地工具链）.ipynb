# %% [markdown]
# # 00_Windows 11 下两种 CUDA 开发环境配置（wsl & 本地工具链）
#
# **Purpose**: Companion notebook for the migrated blog post.
# **Outputs**:
# - Demonstrations related to the topic.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

print('Setup complete.')
