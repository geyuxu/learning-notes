# %% [markdown]
# # 从404到200记一次AstroGitHubPages样式丢失问题的深度排查
#
# **Purpose**: Companion notebook for the migrated blog post.
# **Outputs**:
# - Demonstrations related to the topic.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

print('Setup complete.')
